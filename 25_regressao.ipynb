# %% [markdown]
# <a href="https://colab.research.google.com/github/julia-nosralla/CEE2/blob/main/25_regressao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regressão Linear em Python
#
# ## Introdução
#
# A **Regressão Linear** é uma das técnicas estatísticas e de machine learning mais simples e mais utilizadas para problemas de **previsão numérica**.
#
# > Ela busca encontrar uma **relação linear** entre uma variável dependente (o que queremos prever) e uma ou mais variáveis independentes (os fatores que influenciam).
#
# > Essa formulação também é base para outros modelos de regressão em diversos contextos, como Modelos Lineares Genaralizados (MLG) e regressão em modelos de séries temporais como o SARIMA-X.
# ---
#
# ### Exemplos onde a regressão linear é usada:
#
# - Previsão de preços de imóveis com base em características como tamanho, localização e número de quartos.
# - Estimativa de vendas em função do investimento em marketing.
# - Previsão de consumo elétrico em função da temperatura.
# ---

# %% [markdown]
# ---
# ## Formulação Matemática Básica
#
# ### Regressão Linear Simples
#
# A **Regressão Linear Simples** envolve apenas uma variável independente (exemplo: área de um imóvel).
#
# A equação da reta pode ser representada como:
#
# $$
# y_i = \beta_0 + \beta_1 \cdot x_i + ɛ_i,
# $$
#
# em que, $\beta_0 \in \mathbb{R}$ e $\beta_1 \in \mathbb{R}$, sendo:
#
# - $y$: variável dependente (target, variável resposta, o que queremos prever);
# - $x$: variável independente (feature ou covariável);
# - $\beta_0$: intercepto (valor de $y$ quando $x = 0$);
# - $\beta_1$: coeficiente angular (quanto $y$ varia a cada unidade de $x$);
# - $ɛ$: termo de erro;
#
# ---
#
# ### Regressão Linear Múltipla
#
# Quando temos **mais de uma variável independente**, usamos a **Regressão Linear Múltipla**.
#
# A equação geral é:
#
# $$
# y_i = \beta_0 + \beta_1 \cdot x_{1,i} + \beta_2 \cdot x_{2,i} + \dots + \beta_p \cdot x_{p,i} + ɛ_i
# $$
#
# em que, $( \beta_0, \beta_1, \beta_2, \dots, \beta_p )' \in \mathbb{R}^{p+1}$, sendo:
#
# - $( 1, x_1, x_2, \dots, x_p )'$: vetor de variáveis independentes (o valor 1 é adicionado por conta do intercepto);
# - $( \beta_0, \beta_1, \beta_2, \dots, \beta_p  )'$: vetor de coeficientes associados a cada variável.
#
#
# ---
#
# ### Principais Suposições da Regressão Linear
#
# Antes de aplicar a regressão linear, algumas suposições devem ser consideradas:
#
# - **Linearidade**: A relação entre as variáveis independentes e dependente é linear.
# - **Independência dos erros**: Os erros são independentes.
# - **Homoscedasticidade**: Variância constante dos erros.
# - **Normalidade dos erros**: Os erros seguem uma distribuição Normal.
#
# > As ultimas três podem ser resumidas em $\varepsilon_1, \dots, \varepsilon_n$  i.i.d. Normal($0, \sigma^2$).
# ---
#
# ## Vantagens e Limitações
#
# ### Vantagens:
# - Simplicidade e facilidade de interpretação.
# - Baixo custo computacional.
# - Serve como uma boa baseline para problemas de regressão.
#
# ### Limitações:
# - Não captura relações não lineares de forma eficiente.
# - Sensível a outliers.
# - Depende da validade das suposições estatísticas.
#
# ---

# %% [markdown]
# ---
# ## Formulação Matricial e Estimadores
#
# Para problemas com múltiplas variáveis independentes, é comum representar a regressão linear de forma **matricial**.
#
# ---
#
# ### Representação Matricial
#
# A equação geral da regressão linear múltipla pode ser reescrita como:
# $$
# \mathbf{y} = \mathbf{X} \boldsymbol{\beta} + \boldsymbol{\epsilon}
# $$
# em que:
#
# - $\mathbf{y}$ = vetor coluna de tamanho $n \times 1$ com as observações da variável dependente.
# - $\mathbf{X}$ = matriz de tamanho $n \times (p+1)$, onde:
#   - Cada linha representa uma observação.
#   - Cada coluna representa uma variável independente (incluindo uma coluna de 1s para o intercepto).
# - $\boldsymbol{\beta}$ = vetor dos coeficientes do modelo $(p+1) \times 1$.
# - $\boldsymbol{\epsilon}$ = vetor de erros (resíduos).
#
# ---
#
# ### Estimador dos Mínimos Quadrados Ordinários (OLS)
#
# O objetivo é encontrar o vetor de coeficientes $\boldsymbol{\beta}$ que **minimiza a soma dos quadrados dos resíduos**, isto é,
# $$
# \hat{\boldsymbol{\beta}} = \arg \min \,\sum_{i=1}^n \varepsilon_i^2 = \arg \min \,(\mathbf{y} - \mathbf{X} \boldsymbol{\beta})^\top \,(\mathbf{y} - \mathbf{X} \boldsymbol{\beta})
# $$
#
# A solução analítica do problema de mínimos quadrados é dada por:
# $$
# \hat{\boldsymbol{\beta}} = (\mathbf{X}^\top \mathbf{X})^{-1} \mathbf{X}^\top \mathbf{y}
# $$
# em que:
# - $\hat{\boldsymbol{\beta}}$ = vetor dos coeficientes estimados;
# - $\mathbf{X}^\top$ = transposta da matriz $\mathbf{X}$;
# - $(\mathbf{X}^\top \mathbf{X})^{-1}$ = inversa da matriz $\mathbf{X}^\top \mathbf{X}$.
#
# <br><br>
# > Sob a suposição de normalidade do termo de erro $(\varepsilon_i \sim^{i.i.d.} Normal(0,\sigma^2))$, pode-se mostrar que o Estimador Máxima Verossimilhança (EMV) coincide com o OLS.
#
# <br><br>
# ### Lista de estimadores alternativos:
#
# | Tipo de Estimador                                           | Características                                                                      |
# | ----------------------------------------------------------- | ------------------------------------------------------------------------------------ |
# | **OLS (Ordinary Least Squares)**                            | Assume erros independentes, homocedásticos, sem penalização                          |
# | **WLS (Weighted Least Squares)**                            | Atribui pesos diferentes para cada observação (quando variâncias não são constantes) |
# | **GLS (Generalized Least Squares)**                         | Lida com erros que podem ser correlacionados ou heterocedásticos                     |
# | **Ridge Regression (Mínimos Quadrados com Penalização L2)** | Inclui penalidade para reduzir overfitting                                           |
# | **Lasso Regression (Mínimos Quadrados com Penalização L1)** | Penaliza o valor absoluto dos coeficientes (sparse solutions)                        |
#
# ---

# %% [markdown]
# ---
# ## Ambiente Python 🐍
#
# Antes de começarmos a trabalhar com Regressão Linear em Python, precisamos garantir que todas as bibliotecas necessárias estejam instaladas e devidamente importadas.
#
#
# ### Instalação das Bibliotecas
#
# Se você estiver rodando este notebook no Google Colab, as principais bibliotecas já vêm pré-instaladas. Mas, se estiver rodando localmente, você pode instalar com o seguinte comando:
#
# ```bash
# pip install numpy pandas matplotlib seaborn scikit-learn
# ```
#
# > A biblioteca scikit-learn permite disponibiliza funções para trabalhar com diversos modelos, incluindo os modelos de regressão linear.
#
# > Rode a célula abaixo para carregar as bibliotecas.

# %%
# Manipulação de dados
import numpy as np
import pandas as pd

# Visualização de dados
import matplotlib.pyplot as plt
import seaborn as sns

# Modelagem
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ---
# # Exemplo: Advertising Dataset
#
#
# Vamos trabalhar com o **Advertising Dataset**, que relaciona os investimentos em publicidade (TV, Rádio, Jornal) com o número de vendas de um produto.
#
#
# O dataset contém as seguintes colunas:
#
# | Variável      | Descrição                                                   |
# | ------------- | ----------------------------------------------------------- |
# | **TV**        | Investimento em anúncios de TV (em milhares de dólares)     |
# | **Radio**     | Investimento em anúncios de rádio (em milhares de dólares)  |
# | **Newspaper** | Investimento em anúncios de jornal (em milhares de dólares) |
# | **Sales**     | Vendas do produto (em milhares de unidades)                 |
#
# ---

# %% [markdown]
# ### Carregando e observando a estrutura do conjunto de dados
#
# Nas células abaixo, vamos vericar como os dados são apresentados, número de observações, tipos de variáveis e presença de dados faltantes.

# %%
import pandas as pd

# URL pública para o dataset
url = 'https://www.statlearning.com/s/Advertising.csv'

# Carregar o dataset
df = pd.read_csv(url, index_col=0)

# Visualizar as primeiras linhas
df.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
# Shape do DataFrame (número de linhas e colunas)
print(f"Dimensões do dataset: {df.shape}\n")

# Informações sobre os tipos de dados
df.info()
print("\nOBS: Note que todas as variáveis são contínuas\n")

# Verificar estatísticas descritivas
df.describe()
# Out:
# Dimensões do dataset: (200, 4)
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 7.8 KB
#
# OBS: Note que todas as variáveis são contínuas
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
# Verificando presença de valores faltantes
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %% [markdown]
# ---
# ## Pré-processamento
#
# Nesta etapa vamos fazer um tratamento no conjunto de dados já pensando na modelagem e na avaliação dos modelos.

# %% [markdown]
# ### Separando target e features

# %%
# Target, variável dependente ou variável resposta
y = df['sales']

# Features, variáveis independentes ou covariáveis
X = df.drop('sales',axis=1)

# %% [markdown]
# ### Separando treinamento e teste
#
# Em modelo de regressão é uma boa prática separar uma parte do conjunto de dados como teste, ou seja, vamos separar um subconjunto dos dados que será utilizado para avaliar o modelo fora da amostra de ajuste.
#
# > Também existem técnicas mais gerais e robustas, especialmente utilizadas para conjuntos de dados menores, como *K-fold cross-validation* e *Leave-One-Out Cross-Validation*.
#
# No exemplo, vamos separar:
# - 70% para o treinamento (ajuste do modelo);
# - 30% para o teste (avaliação do modelo fora da amostra).

# %%
from sklearn.model_selection import train_test_split

# Dividir os dados
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f"Tamanho do conjunto de treino: {X_train.shape}")
print(f"Tamanho do conjunto de teste: {X_test.shape}")
# Out:
# Tamanho do conjunto de treino: (140, 3)
# Tamanho do conjunto de teste: (60, 3)

# %% [markdown]
# ### Padronizando features
#
# Diversos modelos de regressão apresentam melhores resultados quando as variáveis possuem a escala padronizada, ou seja, é aplicada uma transformação do tipo $z = (x - \bar{x})/s$ para cada covariável.
#
# - Isto faz com que cada covariável tenha média zero e variância 1;
#
# - Após essa transformação, a variação de uma unidade em uma covariável corresponderá a variação de um desvio-padrão na escala original.

# %%
from sklearn.preprocessing import StandardScaler

# Instanciando o scaler
scaler = StandardScaler()

# Ajustando o scaler com os dados de treino e transformando ambos os conjuntos
# -> retorna numpy.ndarray
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Retorna o formato para dataframe
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns, index=X_test.index)

# %% [markdown]
# ---
# ## Análise Descritiva

# %% [markdown]
# ### Distribuição da variável resposta
#
# - `sales`: vendas do produto (em milhares de unidades).

# %%
plt.figure(figsize=(6, 3))
sns.histplot( y_train, kde=True, bins=15)
plt.title('Distribuição da variável target (Sales)')
plt.xlabel('Sales')
plt.show()

# %% [markdown]
# ### Correlação
#
# > Antes de ajustar o modelo, é interessante verificar como as variáveis independentes se correlacionam com o target.
#
# >> Como estamos interessados em um modelo linear, a correlação de Pearson é adequada.
#
# >>  Analisando o figura, fica claro que a variável `TV` possue alta correlação com a variável resposta `sales`.
#
# >> Relações não lineares ainda podem existir que não são expressas pela correlação de Pearson.

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlação entre Variáveis')
plt.show()

# %% [markdown]
# ---
# ## Regressão Linear Simples
#
# Neste exemplo, vamos relacionar a variável resposta (`sales`) com a variável explicativa `TV`, ou seja, vamos utilizar um modelo com a seguinte equação:
#
# $$
# sales_i = \beta_0 + \beta_1 \times TV_i + ɛ_i,
# $$
#
# em que, $\beta_0 \in \mathbb{R}$, $\beta_1 \in \mathbb{R}$ e $ɛ_1, \dots, ɛ_n$ são i.i.d. Normal$(0,\sigma^2)$.
#
#
# > OBS: lembre que nós padronizados a variável `TV`, ou seja, o modelo proposto vai medir o quanto a variação de um desvio padrão em `TV` afeta `sales`.

# %% [markdown]
# ### Gráfico de dispersão

# %%
plt.figure(figsize=(6, 3))
plt.scatter( x=X_train_scaled['TV'], y=y_train )
plt.xlabel('TV')
plt.ylabel('sales')
plt.show()

# %% [markdown]
# **OBS:** O formato de "cone" apresentado na figura é um indicativo que a suposição de homocedasticidade (variância constante) pode estar violada.
#
# Se essa suposição é violada:
#
# - Os estimadores de $\beta_0$ e $\beta_1$ (os coeficientes) ainda serão não-viesados (o valor médio deles é correto), mas:
#
#   - As inferências (como p-valores e intervalos de confiança) podem ser enganosas.

# %% [markdown]
# Um dos possíveis tratamentos para este problema é utilizar uma transformação:
#
# - A transformação logarítmica costuma ajudar nesse tipo de situação.
#
# - Uma alternativa mais geral, é a transformação de Box-Cox.
#
# > Outra possibilidade seria modelar a variância por meio de um segundo processo de regressão, a qual é estudada na disciplina Modelos Lineares Generalizados (MLG).
#
# Na figura abaixo, vamos utilizar a transformação logarítmica.

# %%
plt.figure(figsize=(6, 3))
plt.scatter(x=X_train_scaled['TV'], y= np.log(y_train))
plt.xlabel('TV')
plt.ylabel('log_sales')
plt.show()

# %% [markdown]
# Essa ultima figura sugere que o modelo abaixo é mais apropriado que o anterior:
# $$
# \log( sales_i ) = \beta_0 + \beta_1 \times TV_i + ɛ_i.
# $$

# %% [markdown]
# ### Ajuste do modelo e resíduos
#
# Vamos inicialmente utilizar a biblioteca `sklearn` e na sequência vamos repetir o processo via a biblioteca `statsmodels.api`.
#
# > `sklearn`: essa biblioteca é mais utilizada no contexto de Aprendizado de Máquina;
#
# > `statsmodels.api`: equivalente ao padrão utilizado em R, geralmente preferida na Estatística.
#
# Afim de verificar a qualidade do modelo, vamos calcular $R^2$ e $R^2_{adj}$, a saber:
#
# |                                         | R²                                                                                       | R² Ajustado                                                                  |
# | --------------------------------------- | ---------------------------------------------------------------------------------------- | ---------------------------------------------------------------------------- |
# | **O que é?**                            | Proporção da variação de Y explicada pelo modelo.                                        | Versão "corrigida" do R² que penaliza o excesso de variáveis no modelo.      |
# | **Fórmula**                             | $R^2 = 1 - \frac{SS_{Res}}{SS_{Tot}}$                                                    | $R^2_{adj} = 1 - \left( \frac{(1 - R^2) \times (n - 1)}{n - p - 1} \right)$  |
# | Onde                                    |                                                                                          | n = número de observações, p = número de variáveis preditoras                |
# | **Interpretação**                       | Mede o quanto da variabilidade de Y o modelo conseguiu explicar com as variáveis usadas. | Ajusta o R² levando em conta a complexidade do modelo (número de variáveis). |
# | **Cresce se adicionar mais variáveis?** | **Sempre aumenta ou se mantém igual**, mesmo que a variável não seja relevante.          | **Só aumenta se a nova variável realmente melhorar o modelo.**               |
# | **Quando usar?**                        | Quando está comparando modelos com o **mesmo número de variáveis**.                      | Quando está comparando **modelos com quantidades diferentes de variáveis**.  |

# %% [markdown]
# #### Via `sklearn`

# %%
# Importando o modelo
from sklearn.linear_model import LinearRegression

# Instanciando o modelo
modelo_1 = LinearRegression( fit_intercept=True )

# Ajustando o modelo aos dados de treino
modelo_1.fit( X_train_scaled[['TV']] , np.log(y_train) )
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Predições ( valores ajustados )
y_pred_log = modelo_1.predict( X_train_scaled[['TV']] )

# R²
r2 = r2_score(np.log(y_train), y_pred_log)

# R² Ajustado
n = X_train_scaled.shape[0]
p = 1  # Número de preditores (apenas TV)
r2_adj = 1 - (1 - r2) * (n - 1) / (n - p - 1)

# Erro Médio Quadrático
mse = mean_squared_error( np.log(y_train), y_pred_log )
rmse = np.sqrt( mse )

# Print "Resumo básico"
print(f"Intercepto (beta_0): {modelo_1.intercept_}")
print(f"Coeficiente TV (beta_1): {modelo_1.coef_[0]}")
print(f"R²: {r2:.4f}")
print(f"R² Ajustado: {r2_adj:.4f}")
print(f"RMSE (na escala log): {rmse:.4f}")
# Out:
# Intercepto (beta_0): 2.5995321118175174
# Coeficiente TV (beta_1): 0.315203197104029
# R²: 0.5704
# R² Ajustado: 0.5673
# RMSE (na escala log): 0.2736

# %% [markdown]
# **Gráfico de dispersão + linha de regressão**

# %%
# Gráfico de dispersão + linha de regressão
plt.figure(figsize=(6, 3))
plt.scatter( X_train_scaled['TV'], np.log(y_train), color='blue', label='Dados reais')
plt.plot( X_train_scaled['TV'], y_pred_log, color='red', label='Predição do modelo', alpha=0.7)
plt.xlabel('Investimento em TV (padronizado)')
plt.ylabel('log sales')
plt.title('Regressão Linear Simples: Sales vs TV')
plt.legend()
plt.show()

# %% [markdown]
# **Gráfico de resíduos vs predição (para verificar homocedasticidade)**
#
# - Queremos ver os resíduos espalhados de forma aleatória ao redor da linha zero.
#
# - Padrões ou funil (heterocedasticidade) são sinais de problemas.

# %%
residuos_log = np.log(y_train) - y_pred_log

plt.figure(figsize=(6, 3))
plt.scatter(y_pred_log, residuos_log, alpha=0.7)
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel('Valores preditos (log-scale)')
plt.ylabel('Resíduos')
plt.title('Resíduos vs Preditos (escala log)')
plt.show()

# %% [markdown]
# #### Via `statsmodels.api`

# %%
import statsmodels.api as sm

# Precisa adicionar o intercepto manualmente
X_sm = sm.add_constant(X_train_scaled[['TV']])

modelo_sm = sm.OLS( np.log(y_train), X_sm ).fit()
print(modelo_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.570
# Model:                            OLS   Adj. R-squared:                  0.567
# Method:                 Least Squares   F-statistic:                     183.2
# Date:                Mon, 23 Jun 2025   Prob (F-statistic):           4.30e-27
# Time:                        14:03:47   Log-Likelihood:                -17.177
# No. Observations:                 140   AIC:                             38.35
# Df Residuals:                     138   BIC:                             44.24
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.5995      0.023    111.631      0.000       2.553       2.646
# ...

# %% [markdown]
# ---
# ## Regressão Linear Multipla
#
# Neste exemplo, vamos relacionar o logaritmo da variável resposta (`sales`) com todas as outras variáveis, ou seja, vamos utilizar um modelo com a seguinte equação:
#
# $$
# \log( sales_i ) = \beta_0 + \beta_1 \times TV_i + \beta_2 \times radio_i + \beta_3 \times newspaper_i + ɛ_i,
# $$
#
# em que, $(\beta_0, \beta_1,\beta_2,\beta_3) \in \mathbb{R^4}\,$ e $\,ɛ_1, \dots, ɛ_n$ são i.i.d. Normal$(0,\sigma^2)$.
#
#
# > OBS: lembre que as covariáveis $TV, radio, newspaper$ foram padronizadas, ou seja, o modelo proposto vai medir o quanto a variação de um desvio padrão em uma dessas variáveis afeta o logaritmo de $sales$.

# %% [markdown]
# ### Ajuste do modelo e resíduos

# %%
# Importando o modelo
from sklearn.linear_model import LinearRegression

# Instanciando o modelo
modelo_2 = LinearRegression( fit_intercept=True )

# Ajustando o modelo aos dados de treino
modelo_2.fit( X_train_scaled, np.log(y_train) )
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Predições
y_pred_log = modelo_2.predict(X_train_scaled)

# R²
r2 = r2_score( np.log(y_train), y_pred_log )

# R² Ajustado
n = X_train_scaled.shape[0]
p = 3  # Número de preditores
r2_adj = 1 - (1 - r2) * (n - 1) / (n - p - 1)

# Erro Médio Quadrático
mse = mean_squared_error( np.log(y_train), y_pred_log )
rmse = np.sqrt(mse)

# Print "Resumo básico"
print(f"Intercepto: {modelo_2.intercept_}")
print(f"Coeficiente TV: {modelo_2.coef_[0]}")
print(f"R²: {r2:.4f}")
print(f"R² Ajustado: {r2_adj:.4f}")
print(f"RMSE (na escala log): {rmse:.4f}")
# Out:
# Intercepto: 2.5995321118175174
# Coeficiente TV: 0.302279029348823
# R²: 0.7845
# R² Ajustado: 0.7797
# RMSE (na escala log): 0.1938

# %% [markdown]
# **Gráfico de resíduos vs predição (para verificar homocedasticidade)**
#
# - Queremos ver os resíduos espalhados de forma aleatória ao redor da linha zero.
#
# - Padrões ou funil (heterocedasticidade) são sinais de problemas.

# %%
residuos_log = np.log(y_train) - y_pred_log

plt.figure(figsize=(6, 3))
plt.scatter(y_pred_log, residuos_log, alpha=0.7)
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel('Valores preditos (log-scale)')
plt.ylabel('Resíduos')
plt.title('Resíduos vs Preditos (escala log)')
plt.show()

# %% [markdown]
# ## Comparando os modelos
#
# **Análise *in-sample*:** Comparando o $R^2_{adj}$ calculado para os dois modelos, temos que o modelo de regressão multipla teve o maior valor e portanto seria o favorito. No entanto, essa informação se baseia unicamente nos dados de treinamento.
#
# **Análise *out-sample*:**  Vamos agora avaliar o desempenho preditivo desses modelos utilizando o conjunto de teste que separamos no início do estudo.
#
#   - Essa análise é especialmente útil pois modelos podem estar super-ajustados, o que é não desejável.
#
#   - Além do mais, tal análise vai permiter ter uma medida mais precisa do desempenho desses modelos fora do conjunto de treino.

# %% [markdown]
# > Na célula abaixo, fazemos a predição para o conjunto de teste, inicialmente na escala logaritmica, na sequência passamos para a escala real e calculamos o erro de predição. Por fim, calculamos um conjunto de métricas afim de comparar os dois modelos em termos do erro de predição.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Predições para "teste" na escala logaritmica
m1_pred_log = modelo_1.predict( X_test_scaled[['TV']] )
m2_pred_log = modelo_2.predict( X_test_scaled )

# Passando para a escala original
m1_pred = np.exp( m1_pred_log )
m2_pred = np.exp( m2_pred_log )

# Calculando erros de previsao
m1_error = y_test - m1_pred
m2_error = y_test - m2_pred

# Métricas para o Modelo 1 (Regressão Simples - TV)
m1_mae = mean_absolute_error(y_test, m1_pred)
m1_mse = mean_squared_error(y_test, m1_pred)
m1_rmse = np.sqrt(m1_mse)
m1_r2 = r2_score(y_test, m1_pred)

# Métricas para o Modelo 2 (Regressão Múltipla - TV + outras variáveis)
m2_mae = mean_absolute_error(y_test, m2_pred)
m2_mse = mean_squared_error(y_test, m2_pred)
m2_rmse = np.sqrt(m2_mse)
m2_r2 = r2_score(y_test, m2_pred)

# Exibindo as métricas lado a lado
print("===== Modelo 1: Regressão Linear Simples (TV) =====")
print(f"MAE: {m1_mae:.4f}")
print(f"MSE: {m1_mse:.4f}")
print(f"RMSE: {m1_rmse:.4f}")
print(f"R²: {m1_r2:.4f}")

print("\n===== Modelo 2: Regressão Linear Múltipla (TV + outras) =====")
print(f"MAE: {m2_mae:.4f}")
print(f"MSE: {m2_mse:.4f}")
print(f"RMSE: {m2_rmse:.4f}")
print(f"R²: {m2_r2:.4f}")
# Out:
# ===== Modelo 1: Regressão Linear Simples (TV) =====
# MAE: 2.2661
# MSE: 9.1301
# RMSE: 3.0216
# R²: 0.6656
#
# ===== Modelo 2: Regressão Linear Múltipla (TV + outras) =====
# MAE: 1.4087
# MSE: 2.7533
# RMSE: 1.6593
# R²: 0.8992

# %% [markdown]
# >> Logo, o modelo de regressão multipla se saiu melhor de acordo com todas as métricas.
#
# No que segue, vamos analisar os erros de predição por meio de gráficos.

# %% [markdown]
# **Boxplot dos erros absolutos**
#
# - Neste gráfico, o modelo que apresentar erros distribuidos em valores menores é o melhor.
#
# > No gráfico abaixo, claramento o modelo de regressão multipla se saiu melhor que o modelo de regressão simples.

# %%
erro_abs_df = pd.DataFrame({
    'Erro Absoluto': np.concatenate([np.abs(m1_error), np.abs(m2_error)]),
    'Modelo': ['Simples'] * len(m1_error) + ['Múltiplo'] * len(m2_error)
})

plt.figure(figsize=(6,4))
sns.boxplot(x='Modelo', y='Erro Absoluto', data=erro_abs_df)
plt.title('Boxplot dos Erros Absolutos')
plt.show()

# %% [markdown]
# **Distribuição acumulada dos erros absolutos**
#
# - Neste gráfico, o modelo que cresce mais rapidamente é o melhor, pois indica que os erros absolutos estão distribuidos em valores mais baixos.
#
# > No gráfico abaixo, claramento o modelo de regressão multipla se saiu melhor que o modelo de regressão simples.

# %%
from statsmodels.distributions.empirical_distribution import ECDF

plt.figure(figsize=(5,3))
ecdf1 = ECDF(np.abs(m1_error))
ecdf2 = ECDF(np.abs(m2_error))

plt.plot(ecdf1.x, ecdf1.y, label='Modelo 1 - Simples', color='blue')
plt.plot(ecdf2.x, ecdf2.y, label='Modelo 2 - Múltiplo', color='green')
plt.xlabel('Erro Absoluto')
plt.ylabel('Probabilidade Acumulada')
plt.title('ECDF dos Erros Absolutos')
plt.legend()
plt.show()

# %% [markdown]
# ---
# # Exercício 1
#
# Faça uma analise exploratória básica do conjunto de dados "Auto MPG", disponível no Seaborn. Trate valores faltantes caso existam, utilize `df.dropna()`.
#
# ```python
# import seaborn as sns
# import pandas as pd
#
# df = sns.load_dataset('mpg')
# df = df.dropna()  # Removendo valores faltantes
# df.head()
# ```
#
# Cada linha representa um carro, com informações como:
#
# - Consumo de combustível (milhas por galão - `mpg`)
# - Potência (`horsepower`)
# - Peso (`weight`)
# - Cilindradas (`displacement`)
# - Aceleração (`acceleration`)
# - Entre outras variáveis.

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset('mpg')
df = df.dropna()  # Removendo valores faltantes
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
# Target, variável dependente ou variável resposta
y = df['mpg']

# Features, variáveis independentes ou covariáveis
columns = ['weight', 'displacement', 'horsepower', 'acceleration']
X = df[columns]

from sklearn.model_selection import train_test_split

# Dividir os dados
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f"Tamanho do conjunto de treino: {X_train.shape}")
print(f"Tamanho do conjunto de teste: {X_test.shape}")
# Out:
# Tamanho do conjunto de treino: (274, 4)
# Tamanho do conjunto de teste: (118, 4)

# %%
from sklearn.preprocessing import StandardScaler

# Instanciando o scaler
scaler = StandardScaler()

# Ajustando o scaler com os dados de treino e transformando ambos os conjuntos
# -> retorna numpy.ndarray
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Retorna o formato para dataframe
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns, index=X_test.index)

# %%
plt.figure(figsize=(6, 3))
sns.histplot(y_train, kde=True)
plt.title('Distribuição da variável target (mpg)')
plt.xlabel('mpg')
plt.show()

# %%
columns = ['mpg', 'weight', 'displacement', 'horsepower', 'acceleration']
correlation_matrix = df[columns].corr()

plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlação entre Variáveis')
plt.show()

# %% [markdown]
# # Exercício 2
#
# Para a variável resposta `mpg`, selecione uma covariável e ajuste um modelo de regressão linear simples. Faça análise de resíduos e analise o $R^2_{adj}$.

# %%
plt.figure(figsize=(6, 3))
plt.scatter(x=X_train_scaled['weight'], y=y_train)
plt.xlabel('weight')
plt.ylabel('mpg')
plt.show()

# %%
# Importando o modelo
from sklearn.linear_model import LinearRegression

# Instanciando o modelo
modelo_1 = LinearRegression( fit_intercept=True )

# Ajustando o modelo aos dados de treino
modelo_1.fit( X_train_scaled[['weight']] , np.log(y_train) )
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Predições ( valores ajustados )
y_pred_log = modelo_1.predict( X_train_scaled[['weight']] )

# R²
r2 = r2_score(np.log(y_train), y_pred_log)

# R² Ajustado
n = X_train_scaled.shape[0]
p = 1  # Número de preditores (apenas TV)
r2_adj = 1 - (1 - r2) * (n - 1) / (n - p - 1)

# Erro Médio Quadrático
mse = mean_squared_error( np.log(y_train), y_pred_log )
rmse = np.sqrt( mse )

# Print "Resumo básico"
print(f"Intercepto (beta_0): {modelo_1.intercept_}")
print(f"Coeficiente weight (beta_1): {modelo_1.coef_[0]}")
print(f"R²: {r2:.4f}")
print(f"R² Ajustado: {r2_adj:.4f}")
print(f"RMSE (na escala log): {rmse:.4f}")
# Out:
# Intercepto (beta_0): 3.1040900032904677
# Coeficiente weight (beta_1): -0.3036329549714432
# R²: 0.7654
# R² Ajustado: 0.7646
# RMSE (na escala log): 0.1681

# %%
# Gráfico de dispersão + linha de regressão
plt.figure(figsize=(6, 3))
plt.scatter( X_train_scaled['weight'], np.log(y_train), label='Dados reais')
plt.plot( X_train_scaled['weight'], y_pred_log, color='red', label='Predição do modelo', alpha=0.7)
plt.xlabel('weight')
plt.ylabel('log mpg')
plt.title('Regressão Linear Simples: mpg vs weight')
plt.legend()
plt.show()

# %%
residuos_log = np.log(y_train) - y_pred_log

plt.figure(figsize=(6, 3))
plt.scatter(y_pred_log, residuos_log, alpha=0.7)
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel('Valores preditos (log-scale)')
plt.ylabel('Resíduos')
plt.title('Resíduos vs Preditos (escala log)')
plt.show()

# %% [markdown]
# # Exercício 3
#
# Para a variável resposta `mpg`, ajuste um modelo de regressão multipla considerando as seguintes covariáveis: `horsepower, weight, displacement, acceleration`. Faça análise de resíduos e analise o $R^2_{adj}$. Compare o $R^2_{adj}$ desse modelo o do Exercício 2.

# %%
# Importando o modelo
from sklearn.linear_model import LinearRegression

# Instanciando o modelo
modelo_2 = LinearRegression( fit_intercept=True )

# Ajustando o modelo aos dados de treino
modelo_2.fit( X_train_scaled, np.log(y_train) )
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Predições
y_pred_log = modelo_2.predict(X_train_scaled)

# R²
r2 = r2_score( np.log(y_train), y_pred_log )

# R² Ajustado
n = X_train_scaled.shape[0]
p = 3  # Número de preditores
r2_adj = 1 - (1 - r2) * (n - 1) / (n - p - 1)

# Erro Médio Quadrático
mse = mean_squared_error( np.log(y_train), y_pred_log )
rmse = np.sqrt(mse)

# Print "Resumo básico"
print(f"Intercepto: {modelo_2.intercept_}")
print(f"Coeficiente weight: {modelo_2.coef_[0]}")
print(f"R²: {r2:.4f}")
print(f"R² Ajustado: {r2_adj:.4f}")
print(f"RMSE (na escala log): {rmse:.4f}")
# Out:
# Intercepto: 3.1040900032904677
# Coeficiente weight: -0.1548164008593864
# R²: 0.7994
# R² Ajustado: 0.7972
# RMSE (na escala log): 0.1554

# %%
residuos_log = np.log(y_train) - y_pred_log

plt.figure(figsize=(6, 3))
plt.scatter(y_pred_log, residuos_log, alpha=0.7)
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel('Valores preditos (log-scale)')
plt.ylabel('Resíduos')
plt.title('Resíduos vs Preditos (escala log)')
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Predições para "teste" na escala logaritmica
m1_pred_log = modelo_1.predict( X_test_scaled[['weight']] )
m2_pred_log = modelo_2.predict( X_test_scaled )

# Passando para a escala original
m1_pred = np.exp( m1_pred_log )
m2_pred = np.exp( m2_pred_log )

# Calculando erros de previsao
m1_error = y_test - m1_pred
m2_error = y_test - m2_pred

# Métricas para o Modelo 1 (Regressão Simples - TV)
m1_mae = mean_absolute_error(y_test, m1_pred)
m1_mse = mean_squared_error(y_test, m1_pred)
m1_rmse = np.sqrt(m1_mse)
m1_r2 = r2_score(y_test, m1_pred)

# Métricas para o Modelo 2 (Regressão Múltipla - TV + outras variáveis)
m2_mae = mean_absolute_error(y_test, m2_pred)
m2_mse = mean_squared_error(y_test, m2_pred)
m2_rmse = np.sqrt(m2_mse)
m2_r2 = r2_score(y_test, m2_pred)

# Exibindo as métricas lado a lado
print("===== Modelo 1: Regressão Linear Simples (weight) =====")
print(f"MAE: {m1_mae:.4f}")
print(f"MSE: {m1_mse:.4f}")
print(f"RMSE: {m1_rmse:.4f}")
print(f"R²: {m1_r2:.4f}")

print("\n===== Modelo 2: Regressão Linear Múltipla (weight + outras) =====")
print(f"MAE: {m2_mae:.4f}")
print(f"MSE: {m2_mse:.4f}")
print(f"RMSE: {m2_rmse:.4f}")
print(f"R²: {m2_r2:.4f}")
# Out:
# ===== Modelo 1: Regressão Linear Simples (weight) =====
# MAE: 3.0683
# MSE: 15.9472
# RMSE: 3.9934
# R²: 0.6986
#
# ===== Modelo 2: Regressão Linear Múltipla (weight + outras) =====
# MAE: 3.0780
# MSE: 15.6217
# RMSE: 3.9524
# R²: 0.7047

# %% [markdown]
# Os R² dos dois modelos são muito próximos, embora seja levemente maior para o segundo modelo.
